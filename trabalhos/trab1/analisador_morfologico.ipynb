# %% [markdown]
# #**Níveis de Analise Linguistica e Análise Lexical e Morfológica Automatizada - Tokenização, Stemming e Lematização**

# %%
"""
Construa um algoritmo para análise morfológica automatizada utilizando a linguagem Python.
O algoritmo deverá receber um texto (cadeia de caracteres) e devolver uma lista de itens, cada qual contendo: 
a forma textual do token, seu lema, sua classe gramatical e flexões (gênero, número, tempo, etc.).
 - O tagset da tarefa de etiquetagem morfossintática (PoS) será o da Universal Dependencies - o mesmo do exmplo no corpus bosque apresentado
  - As flexões a serem consideradas serão:
     - NOUN: Gênero (Gender) e Número (Number)
     - ADJ: Gênero (Gender) e Número (Number)
     - VERB: Gênero (Gender), Pessoa (Person), Tempo (Tense)  e Forma Verbal (VerbForm)
     - PRON: Gênero (Gender) e Número (Number), Tipo (PronType)
     - DET: Gênero (Gender) e Número (Number)
"""
# Out:
# '\nConstrua um algoritmo para análise morfológica automatizada utilizando a linguagem Python.\nO algoritmo deverá receber um texto (cadeia de caracteres) e devolver uma lista de itens, cada qual contendo: \na forma textual do token, seu lema, sua classe gramatical e flexões (gênero, número, tempo, etc.).\n - O tagset da tarefa de etiquetagem morfossintática (PoS) será o da Universal Dependencies - o mesmo do exmplo no corpus bosque apresentado\n  - As flexões a serem consideradas serão:\n     - NOUN: Gênero (Gender) e Número (Number)\n     - ADJ: Gênero (Gender) e Número (Number)\n     - VERB: Gênero (Gender), Pessoa (Person), Tempo (Tense)  e Forma Verbal (VerbForm)\n     - PRON: Gênero (Gender) e Número (Number), Tipo (PronType)\n     - DET: Gênero (Gender) e Número (Number)\n'

# %%
# %pip install conllu
# !wget http://marlovss.work.gd:8080/tomorrow/aula2/bosque.conllu

# %%
import conllu
import itertools as it

class AttributeDict(dict):
    __getattr__ = dict.__getitem__
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__


class CoNLLU:
   def __init__(self, files):
      self.words = []
      self.sentences = []
      for f in files:
         parsed = conllu.parse(open(f, encoding="utf8").read())
         sents = [[AttributeDict(form = token['form'], lemma=token['lemma'],pos=token['upos'],feats=token['feats']) for token in tokenlist if token['upos']!='_'] for tokenlist in parsed]
         self.sentences.extend(sents)
         self.words.extend([word for sent in sents for word in sent])
      self.pos_tags = set([word.pos for word in self.words])
      self.feats_dict ={pos:set(it.chain.from_iterable([list(word.feats.keys()) for word in self.words if word.pos==pos and word.feats!= None])) for pos in self.pos_tags}

bosque = CoNLLU(files=["bosque.conllu"])

# %%
# # Identificação de todos os sufixos e prefixos de tamanho 5

# from nltk.probability import FreqDist

# suffixes = set([word.form.lower()[-5:] for word in bosque.words])
# prefixes = set([word.form.lower()[:5] for word in bosque.words])

# %%
# Em função da demora para rodar o código acima, decidi salvar os resultados em arquivos para uso posterior

# with open("suffixes.txt", "w", encoding="utf-8") as f:
#     for suf in suffixes:
#         f.write(suf + "\n")

# with open("prefixes.txt", "w", encoding="utf-8") as f:
#     for pref in prefixes:
#         f.write(pref + "\n")

# %%
# Carregando os resultados salvos
with open("suffixes.txt", "r", encoding="utf-8") as f:
    suffixes = set([line.strip() for line in f])

with open("prefixes.txt", "r", encoding="utf-8") as f:
    prefixes = set([line.strip() for line in f])

# %%
# Função para análise de sufixos. Para cada sufixo na lista de sufixos, retorna uma lista de dicionários 
# com a classe gramatical e as flexões de cada sufixo
def analyze_suff():
   analyzed = []
   for suf in suffixes:
      for word in bosque.words:
         if word.form.lower()[-5:] == suf:
            analyzed.append({suf: [word.pos, word.feats]})
   return analyzed
            
# Função para análise de prefixos. Para cada prefixo de tamanho qtd_char na lista de prefixos, 
# retorna uma lista de dicionários com o lema de cada prefixo
def analyze_pref(qtd_char):
   analyzed = []
   for pref in prefixes:
      for word in bosque.words:
         if word.form.lower()[:qtd_char] == pref:
            analyzed.append({pref: [word.lemma]})
   return analyzed   

# Sufixos e prefixos (com 5, 4 e 3 caracteres) analisados
# suffixes_analyzed = analyze_suff()
# prefixes_analyzed_5 = analyze_pref(5)
# prefixes_analyzed_4 = analyze_pref(4)
# prefixes_analyzed_3 = analyze_pref(3)

# %%
# Em função da demora para rodar o código acima, decidi salvar a análise dos 
# sufixos e prefixos em arquivos para uso posterior
import json

# with open("suffixes_analyzed.json", "w", encoding="utf-8") as f:
#     json.dump(suffixes_analyzed, f)

# with open("prefixes_analyzed_5.json", "w", encoding="utf-8") as f:
#     json.dump(prefixes_analyzed_5, f)

# with open("prefixes_analyzed_4.json", "w", encoding="utf-8") as f:
#     json.dump(prefixes_analyzed_4, f)

# with open("prefixes_analyzed_3.json", "w", encoding="utf-8") as f:
#     json.dump(prefixes_analyzed_3, f)


# Carregando os sufixos e prefixos (com 5, 4 e 3 caracteres) analisados

with open("suffixes_analyzed.json", "r", encoding="utf-8") as f:
    suffixes_analyzed = json.load(f)

with open("prefixes_analyzed_5.json", "r", encoding="utf-8") as f:
    prefixes_analyzed_5 = json.load(f)

with open("prefixes_analyzed_4.json", "r", encoding="utf-8") as f:
    prefixes_analyzed_4 = json.load(f)

with open("prefixes_analyzed_3.json", "r", encoding="utf-8") as f:
    prefixes_analyzed_3 = json.load(f)

# %%
# Função para análise de um token. Recebe um token e retorna uma lista com a forma textual do token,
# seu lema, sua classe gramatical e flexões (gênero, número, tempo, etc.)
# Certamente, a função poderia ser otimizada, devo revisá-la posteriormente
def tag_token(token):
    # Inicializa a lista de tags com o token
    tags = [token]

    # Inicializa as variáveis para sufixo e prefixo (com 5, 4 e 3 caracteres)
    token_suf = token.lower()[-5:]
    token_pref_5 = token.lower()[:5]
    token_pref_4 = token.lower()[:4]
    token_pref_3 = token.lower()[:3]

    for pref_item in prefixes_analyzed_5:
        # Se o prefixo de 5 caracteres do token estiver na lista de prefixos analisados, 
        # adiciono o lema do token à lista de tags e paro a busca
        if token_pref_5 in pref_item:
            tags.append(pref_item[token_pref_5][0])
            break
    # Se não encontrar o prefixo de 5 caracteres, tento com o de 4 caracteres
    if len(tags) == 1:
        for pref_item in prefixes_analyzed_4:
            if token_pref_4 in pref_item:
                tags.append(pref_item[token_pref_4][0])
                break
    # Se não encontrar o prefixo de 4 caracteres, tento com o de 3 caracteres
    if len(tags) == 1:
        for pref_item in prefixes_analyzed_3:
            if token_pref_3 in pref_item:
                tags.append(pref_item[token_pref_3][0])
                break
    # Se não encontrar nenhum prefixo, adiciono um espaço em branco à lista de tags
    if len(tags) == 1:
        tags.append('_')

    # Para cada sufixo na lista de sufixos analisados, se o sufixo do token estiver na lista de sufixos analisados,
    # adiciono a classe gramatical e as flexões do token à lista de tags
    for suf_item in suffixes_analyzed:
        if token_suf in suf_item:
            tags.append(suf_item[token_suf][0])
            tags.append(suf_item[token_suf][1])
            break
        
    # Se não encontrar o sufixo, adiciono um espaço em branco à lista de tags
    if len(tags) < 3:
        tags.append('_')
        tags.append('_')
    
    return tags


# Função para análise de uma lista de tokens. Recebe uma lista de tokens e retorna uma lista de itens,
# cada qual contendo a forma textual do token, seu lema, sua classe gramatical e flexões (gênero, número, tempo, etc.)
def tag(tokens):
   tagged = []
   for token in tokens:
      tagged.append((tag_token(token)))
   
   return tagged

# %%
test = CoNLLU(files=["test.conllu"])
test_sents = [[word.form for word in sent] for sent in test.sentences]
gold = [[(word.form, word.lemma, word.pos, word.feats) for word in sent] for sent in test.sentences]
predicted = []

# Analisando as sentenças de teste
i = 1
for sent in test_sents:
   print(i, "sentença analisada de", len(test_sents))
   i += 1
   predicted.append((tag(sent)))
# Out:
# 1 sentença analisada de 1167
# 2 sentença analisada de 1167
# 3 sentença analisada de 1167
# 4 sentença analisada de 1167
# 5 sentença analisada de 1167
# 6 sentença analisada de 1167
# 7 sentença analisada de 1167
# 8 sentença analisada de 1167
# 9 sentença analisada de 1167
# 10 sentença analisada de 1167
# 11 sentença analisada de 1167
# 12 sentença analisada de 1167
# 13 sentença analisada de 1167
# 14 sentença analisada de 1167
# 15 sentença analisada de 1167
# 16 sentença analisada de 1167
# 17 sentença analisada de 1167
# 18 sentença analisada de 1167
# 19 sentença analisada de 1167
# 20 sentença analisada de 1167
# 21 sentença analisada de 1167
# 22 sentença analisada de 1167
# 23 sentença analisada de 1167
# 24 sentença analisada de 1167
# 25 sentença analisada de 1167
# 26 sentença analisada de 1167
# 27 sentença analisada de 1167
# 28 sentença analisada de 1167
# 29 sentença analisada de 1167
# 30 sentença analisada de 1167
# 31 sentença analisada de 1167
# 32 sentença analisada de 1167
# 33 sentença analisada de 1167
# 34 sentença analisada de 1167
# 35 sentença analisada de 1167
# 36 sentença analisada de 1167
# 37 sentença analisada de 1167
# 38 sentença analisada de 1167
# 39 sentença analisada de 1167
# 40 sentença analisada de 1167
# 41 sentença analisada de 1167
# 42 sentença analisada de 1167
# 43 sentença analisada de 1167
# 44 sentença analisada de 1167
# 45 sentença analisada de 1167
# 46 sentença analisada de 1167
# 47 sentença analisada de 1167
# 48 sentença analisada de 1167
# 49 sentença analisada de 1167
# 50 sentença analisada de 1167
# 51 sentença analisada de 1167
# 52 sentença analisada de 1167
# 53 sentença analisada de 1167
# 54 sentença analisada de 1167
# 55 sentença analisada de 1167
# 56 sentença analisada de 1167
# 57 sentença analisada de 1167
# 58 sentença analisada de 1167
# 59 sentença analisada de 1167
# 60 sentença analisada de 1167
# 61 sentença analisada de 1167
# 62 sentença analisada de 1167
# 63 sentença analisada de 1167
# 64 sentença analisada de 1167
# 65 sentença analisada de 1167
# 66 sentença analisada de 1167
# 67 sentença analisada de 1167
# 68 sentença analisada de 1167
# 69 sentença analisada de 1167
# 70 sentença analisada de 1167
# 71 sentença analisada de 1167
# 72 sentença analisada de 1167
# 73 sentença analisada de 1167
# 74 sentença analisada de 1167
# 75 sentença analisada de 1167
# 76 sentença analisada de 1167
# 77 sentença analisada de 1167
# 78 sentença analisada de 1167
# 79 sentença analisada de 1167
# 80 sentença analisada de 1167
# 81 sentença analisada de 1167
# 82 sentença analisada de 1167
# 83 sentença analisada de 1167
# 84 sentença analisada de 1167
# 85 sentença analisada de 1167
# 86 sentença analisada de 1167
# 87 sentença analisada de 1167
# 88 sentença analisada de 1167
# 89 sentença analisada de 1167
# 90 sentença analisada de 1167
# 91 sentença analisada de 1167
# 92 sentença analisada de 1167
# 93 sentença analisada de 1167
# 94 sentença analisada de 1167
# 95 sentença analisada de 1167
# 96 sentença analisada de 1167
# 97 sentença analisada de 1167
# 98 sentença analisada de 1167
# 99 sentença analisada de 1167
# 100 sentença analisada de 1167
# 101 sentença analisada de 1167
# 102 sentença analisada de 1167
# 103 sentença analisada de 1167
# 104 sentença analisada de 1167
# 105 sentença analisada de 1167
# 106 sentença analisada de 1167
# 107 sentença analisada de 1167
# 108 sentença analisada de 1167
# 109 sentença analisada de 1167
# 110 sentença analisada de 1167
# 111 sentença analisada de 1167
# 112 sentença analisada de 1167
# 113 sentença analisada de 1167
# 114 sentença analisada de 1167
# 115 sentença analisada de 1167
# 116 sentença analisada de 1167
# 117 sentença analisada de 1167
# 118 sentença analisada de 1167
# 119 sentença analisada de 1167
# 120 sentença analisada de 1167
# 121 sentença analisada de 1167
# 122 sentença analisada de 1167
# 123 sentença analisada de 1167
# 124 sentença analisada de 1167
# 125 sentença analisada de 1167
# 126 sentença analisada de 1167
# 127 sentença analisada de 1167
# 128 sentença analisada de 1167
# 129 sentença analisada de 1167
# 130 sentença analisada de 1167
# 131 sentença analisada de 1167
# 132 sentença analisada de 1167
# 133 sentença analisada de 1167
# 134 sentença analisada de 1167
# 135 sentença analisada de 1167
# 136 sentença analisada de 1167
# 137 sentença analisada de 1167
# 138 sentença analisada de 1167
# 139 sentença analisada de 1167
# 140 sentença analisada de 1167
# 141 sentença analisada de 1167
# 142 sentença analisada de 1167
# 143 sentença analisada de 1167
# 144 sentença analisada de 1167
# 145 sentença analisada de 1167
# 146 sentença analisada de 1167
# 147 sentença analisada de 1167
# 148 sentença analisada de 1167
# 149 sentença analisada de 1167
# 150 sentença analisada de 1167
# 151 sentença analisada de 1167
# 152 sentença analisada de 1167
# 153 sentença analisada de 1167
# 154 sentença analisada de 1167
# 155 sentença analisada de 1167
# 156 sentença analisada de 1167
# 157 sentença analisada de 1167
# 158 sentença analisada de 1167
# 159 sentença analisada de 1167
# 160 sentença analisada de 1167
# 161 sentença analisada de 1167
# 162 sentença analisada de 1167
# 163 sentença analisada de 1167
# 164 sentença analisada de 1167
# 165 sentença analisada de 1167
# 166 sentença analisada de 1167
# 167 sentença analisada de 1167
# 168 sentença analisada de 1167
# 169 sentença analisada de 1167
# 170 sentença analisada de 1167
# 171 sentença analisada de 1167
# 172 sentença analisada de 1167
# 173 sentença analisada de 1167
# 174 sentença analisada de 1167
# 175 sentença analisada de 1167
# 176 sentença analisada de 1167
# 177 sentença analisada de 1167
# 178 sentença analisada de 1167
# 179 sentença analisada de 1167
# 180 sentença analisada de 1167
# 181 sentença analisada de 1167
# 182 sentença analisada de 1167
# 183 sentença analisada de 1167
# 184 sentença analisada de 1167
# 185 sentença analisada de 1167
# 186 sentença analisada de 1167
# 187 sentença analisada de 1167
# 188 sentença analisada de 1167
# 189 sentença analisada de 1167
# 190 sentença analisada de 1167
# 191 sentença analisada de 1167
# 192 sentença analisada de 1167
# 193 sentença analisada de 1167
# 194 sentença analisada de 1167
# 195 sentença analisada de 1167
# 196 sentença analisada de 1167
# 197 sentença analisada de 1167
# 198 sentença analisada de 1167
# 199 sentença analisada de 1167
# 200 sentença analisada de 1167
# 201 sentença analisada de 1167
# 202 sentença analisada de 1167
# 203 sentença analisada de 1167
# 204 sentença analisada de 1167
# 205 sentença analisada de 1167
# 206 sentença analisada de 1167
# 207 sentença analisada de 1167
# 208 sentença analisada de 1167
# 209 sentença analisada de 1167
# 210 sentença analisada de 1167
# 211 sentença analisada de 1167
# 212 sentença analisada de 1167
# 213 sentença analisada de 1167
# 214 sentença analisada de 1167
# 215 sentença analisada de 1167
# 216 sentença analisada de 1167
# 217 sentença analisada de 1167
# 218 sentença analisada de 1167
# 219 sentença analisada de 1167
# 220 sentença analisada de 1167
# 221 sentença analisada de 1167
# 222 sentença analisada de 1167
# 223 sentença analisada de 1167
# 224 sentença analisada de 1167
# 225 sentença analisada de 1167
# 226 sentença analisada de 1167
# 227 sentença analisada de 1167
# 228 sentença analisada de 1167
# 229 sentença analisada de 1167
# 230 sentença analisada de 1167
# 231 sentença analisada de 1167
# 232 sentença analisada de 1167
# 233 sentença analisada de 1167
# 234 sentença analisada de 1167
# 235 sentença analisada de 1167
# 236 sentença analisada de 1167
# 237 sentença analisada de 1167
# 238 sentença analisada de 1167
# 239 sentença analisada de 1167
# 240 sentença analisada de 1167
# 241 sentença analisada de 1167
# 242 sentença analisada de 1167
# 243 sentença analisada de 1167
# 244 sentença analisada de 1167
# 245 sentença analisada de 1167
# 246 sentença analisada de 1167
# 247 sentença analisada de 1167
# 248 sentença analisada de 1167
# 249 sentença analisada de 1167
# 250 sentença analisada de 1167
# 251 sentença analisada de 1167
# 252 sentença analisada de 1167
# 253 sentença analisada de 1167
# 254 sentença analisada de 1167
# 255 sentença analisada de 1167
# 256 sentença analisada de 1167
# 257 sentença analisada de 1167
# 258 sentença analisada de 1167
# 259 sentença analisada de 1167
# 260 sentença analisada de 1167
# 261 sentença analisada de 1167
# 262 sentença analisada de 1167
# 263 sentença analisada de 1167
# 264 sentença analisada de 1167
# 265 sentença analisada de 1167
# 266 sentença analisada de 1167
# 267 sentença analisada de 1167
# 268 sentença analisada de 1167
# 269 sentença analisada de 1167
# 270 sentença analisada de 1167
# 271 sentença analisada de 1167
# 272 sentença analisada de 1167
# 273 sentença analisada de 1167
# 274 sentença analisada de 1167
# 275 sentença analisada de 1167
# 276 sentença analisada de 1167
# 277 sentença analisada de 1167
# 278 sentença analisada de 1167
# 279 sentença analisada de 1167
# 280 sentença analisada de 1167
# 281 sentença analisada de 1167
# 282 sentença analisada de 1167
# 283 sentença analisada de 1167
# 284 sentença analisada de 1167
# 285 sentença analisada de 1167
# 286 sentença analisada de 1167
# 287 sentença analisada de 1167
# 288 sentença analisada de 1167
# 289 sentença analisada de 1167
# 290 sentença analisada de 1167
# 291 sentença analisada de 1167
# 292 sentença analisada de 1167
# 293 sentença analisada de 1167
# 294 sentença analisada de 1167
# 295 sentença analisada de 1167
# 296 sentença analisada de 1167
# 297 sentença analisada de 1167
# 298 sentença analisada de 1167
# 299 sentença analisada de 1167
# 300 sentença analisada de 1167
# 301 sentença analisada de 1167
# 302 sentença analisada de 1167
# 303 sentença analisada de 1167
# 304 sentença analisada de 1167
# 305 sentença analisada de 1167
# 306 sentença analisada de 1167
# 307 sentença analisada de 1167
# 308 sentença analisada de 1167
# 309 sentença analisada de 1167
# 310 sentença analisada de 1167
# 311 sentença analisada de 1167
# 312 sentença analisada de 1167
# 313 sentença analisada de 1167
# 314 sentença analisada de 1167
# 315 sentença analisada de 1167
# 316 sentença analisada de 1167
# 317 sentença analisada de 1167
# 318 sentença analisada de 1167
# 319 sentença analisada de 1167
# 320 sentença analisada de 1167
# 321 sentença analisada de 1167
# 322 sentença analisada de 1167
# 323 sentença analisada de 1167
# 324 sentença analisada de 1167
# 325 sentença analisada de 1167
# 326 sentença analisada de 1167
# 327 sentença analisada de 1167
# 328 sentença analisada de 1167
# 329 sentença analisada de 1167
# 330 sentença analisada de 1167
# 331 sentença analisada de 1167
# 332 sentença analisada de 1167
# 333 sentença analisada de 1167
# 334 sentença analisada de 1167
# 335 sentença analisada de 1167
# 336 sentença analisada de 1167
# 337 sentença analisada de 1167
# 338 sentença analisada de 1167
# 339 sentença analisada de 1167
# 340 sentença analisada de 1167
# 341 sentença analisada de 1167
# 342 sentença analisada de 1167
# 343 sentença analisada de 1167
# 344 sentença analisada de 1167
# 345 sentença analisada de 1167
# 346 sentença analisada de 1167
# 347 sentença analisada de 1167
# 348 sentença analisada de 1167
# 349 sentença analisada de 1167
# 350 sentença analisada de 1167
# 351 sentença analisada de 1167
# 352 sentença analisada de 1167
# 353 sentença analisada de 1167
# 354 sentença analisada de 1167
# 355 sentença analisada de 1167
# 356 sentença analisada de 1167
# 357 sentença analisada de 1167
# 358 sentença analisada de 1167
# 359 sentença analisada de 1167
# 360 sentença analisada de 1167
# 361 sentença analisada de 1167
# 362 sentença analisada de 1167
# 363 sentença analisada de 1167
# 364 sentença analisada de 1167
# 365 sentença analisada de 1167
# 366 sentença analisada de 1167
# 367 sentença analisada de 1167
# 368 sentença analisada de 1167
# 369 sentença analisada de 1167
# 370 sentença analisada de 1167
# 371 sentença analisada de 1167
# 372 sentença analisada de 1167
# 373 sentença analisada de 1167
# 374 sentença analisada de 1167
# 375 sentença analisada de 1167
# 376 sentença analisada de 1167
# 377 sentença analisada de 1167
# 378 sentença analisada de 1167
# 379 sentença analisada de 1167
# 380 sentença analisada de 1167
# 381 sentença analisada de 1167
# 382 sentença analisada de 1167
# 383 sentença analisada de 1167
# 384 sentença analisada de 1167
# 385 sentença analisada de 1167
# 386 sentença analisada de 1167
# 387 sentença analisada de 1167
# 388 sentença analisada de 1167
# 389 sentença analisada de 1167
# 390 sentença analisada de 1167
# 391 sentença analisada de 1167
# 392 sentença analisada de 1167
# 393 sentença analisada de 1167
# 394 sentença analisada de 1167
# 395 sentença analisada de 1167
# 396 sentença analisada de 1167
# 397 sentença analisada de 1167
# 398 sentença analisada de 1167
# 399 sentença analisada de 1167
# 400 sentença analisada de 1167
# 401 sentença analisada de 1167
# 402 sentença analisada de 1167
# 403 sentença analisada de 1167
# 404 sentença analisada de 1167
# 405 sentença analisada de 1167
# 406 sentença analisada de 1167
# 407 sentença analisada de 1167
# 408 sentença analisada de 1167
# 409 sentença analisada de 1167
# 410 sentença analisada de 1167
# 411 sentença analisada de 1167
# 412 sentença analisada de 1167
# 413 sentença analisada de 1167
# 414 sentença analisada de 1167
# 415 sentença analisada de 1167
# 416 sentença analisada de 1167
# 417 sentença analisada de 1167
# 418 sentença analisada de 1167
# 419 sentença analisada de 1167
# 420 sentença analisada de 1167
# 421 sentença analisada de 1167
# 422 sentença analisada de 1167
# 423 sentença analisada de 1167
# 424 sentença analisada de 1167
# 425 sentença analisada de 1167
# 426 sentença analisada de 1167
# 427 sentença analisada de 1167
# 428 sentença analisada de 1167
# 429 sentença analisada de 1167
# 430 sentença analisada de 1167
# 431 sentença analisada de 1167
# 432 sentença analisada de 1167
# 433 sentença analisada de 1167
# 434 sentença analisada de 1167
# 435 sentença analisada de 1167
# 436 sentença analisada de 1167
# 437 sentença analisada de 1167
# 438 sentença analisada de 1167
# 439 sentença analisada de 1167
# 440 sentença analisada de 1167
# 441 sentença analisada de 1167
# 442 sentença analisada de 1167
# 443 sentença analisada de 1167
# 444 sentença analisada de 1167
# 445 sentença analisada de 1167
# 446 sentença analisada de 1167
# 447 sentença analisada de 1167
# 448 sentença analisada de 1167
# 449 sentença analisada de 1167
# 450 sentença analisada de 1167
# 451 sentença analisada de 1167
# 452 sentença analisada de 1167
# 453 sentença analisada de 1167
# 454 sentença analisada de 1167
# 455 sentença analisada de 1167
# 456 sentença analisada de 1167
# 457 sentença analisada de 1167
# 458 sentença analisada de 1167
# 459 sentença analisada de 1167
# 460 sentença analisada de 1167
# 461 sentença analisada de 1167
# 462 sentença analisada de 1167
# 463 sentença analisada de 1167
# 464 sentença analisada de 1167
# 465 sentença analisada de 1167
# 466 sentença analisada de 1167
# 467 sentença analisada de 1167
# 468 sentença analisada de 1167
# 469 sentença analisada de 1167
# 470 sentença analisada de 1167
# 471 sentença analisada de 1167
# 472 sentença analisada de 1167
# 473 sentença analisada de 1167
# 474 sentença analisada de 1167
# 475 sentença analisada de 1167
# 476 sentença analisada de 1167
# 477 sentença analisada de 1167
# 478 sentença analisada de 1167
# 479 sentença analisada de 1167
# 480 sentença analisada de 1167
# 481 sentença analisada de 1167
# 482 sentença analisada de 1167
# 483 sentença analisada de 1167
# 484 sentença analisada de 1167
# 485 sentença analisada de 1167
# 486 sentença analisada de 1167
# 487 sentença analisada de 1167
# 488 sentença analisada de 1167
# 489 sentença analisada de 1167
# 490 sentença analisada de 1167
# 491 sentença analisada de 1167
# 492 sentença analisada de 1167
# 493 sentença analisada de 1167
# 494 sentença analisada de 1167
# 495 sentença analisada de 1167
# 496 sentença analisada de 1167
# 497 sentença analisada de 1167
# 498 sentença analisada de 1167
# 499 sentença analisada de 1167
# 500 sentença analisada de 1167
# 501 sentença analisada de 1167
# 502 sentença analisada de 1167
# 503 sentença analisada de 1167
# 504 sentença analisada de 1167
# 505 sentença analisada de 1167
# 506 sentença analisada de 1167
# 507 sentença analisada de 1167
# 508 sentença analisada de 1167
# 509 sentença analisada de 1167
# 510 sentença analisada de 1167
# 511 sentença analisada de 1167
# 512 sentença analisada de 1167
# 513 sentença analisada de 1167
# 514 sentença analisada de 1167
# 515 sentença analisada de 1167
# 516 sentença analisada de 1167
# 517 sentença analisada de 1167
# 518 sentença analisada de 1167
# 519 sentença analisada de 1167
# 520 sentença analisada de 1167
# 521 sentença analisada de 1167
# 522 sentença analisada de 1167
# 523 sentença analisada de 1167
# 524 sentença analisada de 1167
# 525 sentença analisada de 1167
# 526 sentença analisada de 1167
# 527 sentença analisada de 1167
# 528 sentença analisada de 1167
# 529 sentença analisada de 1167
# 530 sentença analisada de 1167
# 531 sentença analisada de 1167
# 532 sentença analisada de 1167
# 533 sentença analisada de 1167
# 534 sentença analisada de 1167
# 535 sentença analisada de 1167
# 536 sentença analisada de 1167
# 537 sentença analisada de 1167
# 538 sentença analisada de 1167
# 539 sentença analisada de 1167
# 540 sentença analisada de 1167
# 541 sentença analisada de 1167
# 542 sentença analisada de 1167
# 543 sentença analisada de 1167
# 544 sentença analisada de 1167
# 545 sentença analisada de 1167
# 546 sentença analisada de 1167
# 547 sentença analisada de 1167
# 548 sentença analisada de 1167
# 549 sentença analisada de 1167
# 550 sentença analisada de 1167
# 551 sentença analisada de 1167
# 552 sentença analisada de 1167
# 553 sentença analisada de 1167
# 554 sentença analisada de 1167
# 555 sentença analisada de 1167
# 556 sentença analisada de 1167
# 557 sentença analisada de 1167
# 558 sentença analisada de 1167
# 559 sentença analisada de 1167
# 560 sentença analisada de 1167
# 561 sentença analisada de 1167
# 562 sentença analisada de 1167
# 563 sentença analisada de 1167
# 564 sentença analisada de 1167
# 565 sentença analisada de 1167
# 566 sentença analisada de 1167
# 567 sentença analisada de 1167
# 568 sentença analisada de 1167
# 569 sentença analisada de 1167
# 570 sentença analisada de 1167
# 571 sentença analisada de 1167
# 572 sentença analisada de 1167
# 573 sentença analisada de 1167
# 574 sentença analisada de 1167
# 575 sentença analisada de 1167
# 576 sentença analisada de 1167
# 577 sentença analisada de 1167
# 578 sentença analisada de 1167
# 579 sentença analisada de 1167
# 580 sentença analisada de 1167
# 581 sentença analisada de 1167
# 582 sentença analisada de 1167
# 583 sentença analisada de 1167
# 584 sentença analisada de 1167
# 585 sentença analisada de 1167
# 586 sentença analisada de 1167
# 587 sentença analisada de 1167
# 588 sentença analisada de 1167
# 589 sentença analisada de 1167
# 590 sentença analisada de 1167
# 591 sentença analisada de 1167
# 592 sentença analisada de 1167
# 593 sentença analisada de 1167
# 594 sentença analisada de 1167
# 595 sentença analisada de 1167
# 596 sentença analisada de 1167
# 597 sentença analisada de 1167
# 598 sentença analisada de 1167
# 599 sentença analisada de 1167
# 600 sentença analisada de 1167
# 601 sentença analisada de 1167
# 602 sentença analisada de 1167
# 603 sentença analisada de 1167
# 604 sentença analisada de 1167
# 605 sentença analisada de 1167
# 606 sentença analisada de 1167
# 607 sentença analisada de 1167
# 608 sentença analisada de 1167
# 609 sentença analisada de 1167
# 610 sentença analisada de 1167
# 611 sentença analisada de 1167
# 612 sentença analisada de 1167
# 613 sentença analisada de 1167
# 614 sentença analisada de 1167
# 615 sentença analisada de 1167
# 616 sentença analisada de 1167
# 617 sentença analisada de 1167
# 618 sentença analisada de 1167
# 619 sentença analisada de 1167
# 620 sentença analisada de 1167
# 621 sentença analisada de 1167
# 622 sentença analisada de 1167
# 623 sentença analisada de 1167
# 624 sentença analisada de 1167
# 625 sentença analisada de 1167
# 626 sentença analisada de 1167
# 627 sentença analisada de 1167
# 628 sentença analisada de 1167
# 629 sentença analisada de 1167
# 630 sentença analisada de 1167
# 631 sentença analisada de 1167
# 632 sentença analisada de 1167
# 633 sentença analisada de 1167
# 634 sentença analisada de 1167
# 635 sentença analisada de 1167
# 636 sentença analisada de 1167
# 637 sentença analisada de 1167
# 638 sentença analisada de 1167
# 639 sentença analisada de 1167
# 640 sentença analisada de 1167
# 641 sentença analisada de 1167
# 642 sentença analisada de 1167
# 643 sentença analisada de 1167
# 644 sentença analisada de 1167
# 645 sentença analisada de 1167
# 646 sentença analisada de 1167
# 647 sentença analisada de 1167
# 648 sentença analisada de 1167
# 649 sentença analisada de 1167
# 650 sentença analisada de 1167
# 651 sentença analisada de 1167
# 652 sentença analisada de 1167
# 653 sentença analisada de 1167
# 654 sentença analisada de 1167
# 655 sentença analisada de 1167
# 656 sentença analisada de 1167
# 657 sentença analisada de 1167
# 658 sentença analisada de 1167
# 659 sentença analisada de 1167
# 660 sentença analisada de 1167
# 661 sentença analisada de 1167
# 662 sentença analisada de 1167
# 663 sentença analisada de 1167
# 664 sentença analisada de 1167
# 665 sentença analisada de 1167
# 666 sentença analisada de 1167
# 667 sentença analisada de 1167
# 668 sentença analisada de 1167
# 669 sentença analisada de 1167
# 670 sentença analisada de 1167
# 671 sentença analisada de 1167
# 672 sentença analisada de 1167
# 673 sentença analisada de 1167
# 674 sentença analisada de 1167
# 675 sentença analisada de 1167
# 676 sentença analisada de 1167
# 677 sentença analisada de 1167
# 678 sentença analisada de 1167
# 679 sentença analisada de 1167
# 680 sentença analisada de 1167
# 681 sentença analisada de 1167
# 682 sentença analisada de 1167
# 683 sentença analisada de 1167
# 684 sentença analisada de 1167
# 685 sentença analisada de 1167
# 686 sentença analisada de 1167
# 687 sentença analisada de 1167
# 688 sentença analisada de 1167
# 689 sentença analisada de 1167
# 690 sentença analisada de 1167
# 691 sentença analisada de 1167
# 692 sentença analisada de 1167
# 693 sentença analisada de 1167
# 694 sentença analisada de 1167
# 695 sentença analisada de 1167
# 696 sentença analisada de 1167
# 697 sentença analisada de 1167
# 698 sentença analisada de 1167
# 699 sentença analisada de 1167
# 700 sentença analisada de 1167
# 701 sentença analisada de 1167
# 702 sentença analisada de 1167
# 703 sentença analisada de 1167
# 704 sentença analisada de 1167
# 705 sentença analisada de 1167
# 706 sentença analisada de 1167
# 707 sentença analisada de 1167
# 708 sentença analisada de 1167
# 709 sentença analisada de 1167
# 710 sentença analisada de 1167
# 711 sentença analisada de 1167
# 712 sentença analisada de 1167
# 713 sentença analisada de 1167
# 714 sentença analisada de 1167
# 715 sentença analisada de 1167
# 716 sentença analisada de 1167
# 717 sentença analisada de 1167
# 718 sentença analisada de 1167
# 719 sentença analisada de 1167
# 720 sentença analisada de 1167
# 721 sentença analisada de 1167
# 722 sentença analisada de 1167
# 723 sentença analisada de 1167
# 724 sentença analisada de 1167
# 725 sentença analisada de 1167
# 726 sentença analisada de 1167
# 727 sentença analisada de 1167
# 728 sentença analisada de 1167
# 729 sentença analisada de 1167
# 730 sentença analisada de 1167
# 731 sentença analisada de 1167
# 732 sentença analisada de 1167
# 733 sentença analisada de 1167
# 734 sentença analisada de 1167
# 735 sentença analisada de 1167
# 736 sentença analisada de 1167
# 737 sentença analisada de 1167
# 738 sentença analisada de 1167
# 739 sentença analisada de 1167
# 740 sentença analisada de 1167
# 741 sentença analisada de 1167
# 742 sentença analisada de 1167
# 743 sentença analisada de 1167
# 744 sentença analisada de 1167
# 745 sentença analisada de 1167
# 746 sentença analisada de 1167
# 747 sentença analisada de 1167
# 748 sentença analisada de 1167
# 749 sentença analisada de 1167
# 750 sentença analisada de 1167
# 751 sentença analisada de 1167
# 752 sentença analisada de 1167
# 753 sentença analisada de 1167
# 754 sentença analisada de 1167
# 755 sentença analisada de 1167
# 756 sentença analisada de 1167
# 757 sentença analisada de 1167
# 758 sentença analisada de 1167
# 759 sentença analisada de 1167
# 760 sentença analisada de 1167
# 761 sentença analisada de 1167
# 762 sentença analisada de 1167
# 763 sentença analisada de 1167
# 764 sentença analisada de 1167
# 765 sentença analisada de 1167
# 766 sentença analisada de 1167
# 767 sentença analisada de 1167
# 768 sentença analisada de 1167
# 769 sentença analisada de 1167
# 770 sentença analisada de 1167
# 771 sentença analisada de 1167
# 772 sentença analisada de 1167
# 773 sentença analisada de 1167
# 774 sentença analisada de 1167
# 775 sentença analisada de 1167
# 776 sentença analisada de 1167
# 777 sentença analisada de 1167
# 778 sentença analisada de 1167
# 779 sentença analisada de 1167
# 780 sentença analisada de 1167
# 781 sentença analisada de 1167
# 782 sentença analisada de 1167
# 783 sentença analisada de 1167
# 784 sentença analisada de 1167
# 785 sentença analisada de 1167
# 786 sentença analisada de 1167
# 787 sentença analisada de 1167
# 788 sentença analisada de 1167
# 789 sentença analisada de 1167
# 790 sentença analisada de 1167
# 791 sentença analisada de 1167
# 792 sentença analisada de 1167
# 793 sentença analisada de 1167
# 794 sentença analisada de 1167
# 795 sentença analisada de 1167
# 796 sentença analisada de 1167
# 797 sentença analisada de 1167
# 798 sentença analisada de 1167
# 799 sentença analisada de 1167
# 800 sentença analisada de 1167
# 801 sentença analisada de 1167
# 802 sentença analisada de 1167
# 803 sentença analisada de 1167
# 804 sentença analisada de 1167
# 805 sentença analisada de 1167
# 806 sentença analisada de 1167
# 807 sentença analisada de 1167
# 808 sentença analisada de 1167
# 809 sentença analisada de 1167
# 810 sentença analisada de 1167
# 811 sentença analisada de 1167
# 812 sentença analisada de 1167
# 813 sentença analisada de 1167
# 814 sentença analisada de 1167
# 815 sentença analisada de 1167
# 816 sentença analisada de 1167
# 817 sentença analisada de 1167
# 818 sentença analisada de 1167
# 819 sentença analisada de 1167
# 820 sentença analisada de 1167
# 821 sentença analisada de 1167
# 822 sentença analisada de 1167
# 823 sentença analisada de 1167
# 824 sentença analisada de 1167
# 825 sentença analisada de 1167
# 826 sentença analisada de 1167
# 827 sentença analisada de 1167
# 828 sentença analisada de 1167
# 829 sentença analisada de 1167
# 830 sentença analisada de 1167
# 831 sentença analisada de 1167
# 832 sentença analisada de 1167
# 833 sentença analisada de 1167
# 834 sentença analisada de 1167
# 835 sentença analisada de 1167
# 836 sentença analisada de 1167
# 837 sentença analisada de 1167
# 838 sentença analisada de 1167
# 839 sentença analisada de 1167
# 840 sentença analisada de 1167
# 841 sentença analisada de 1167
# 842 sentença analisada de 1167
# 843 sentença analisada de 1167
# 844 sentença analisada de 1167
# 845 sentença analisada de 1167
# 846 sentença analisada de 1167
# 847 sentença analisada de 1167
# 848 sentença analisada de 1167
# 849 sentença analisada de 1167
# 850 sentença analisada de 1167
# 851 sentença analisada de 1167
# 852 sentença analisada de 1167
# 853 sentença analisada de 1167
# 854 sentença analisada de 1167
# 855 sentença analisada de 1167
# 856 sentença analisada de 1167
# 857 sentença analisada de 1167
# 858 sentença analisada de 1167
# 859 sentença analisada de 1167
# 860 sentença analisada de 1167
# 861 sentença analisada de 1167
# 862 sentença analisada de 1167
# 863 sentença analisada de 1167
# 864 sentença analisada de 1167
# 865 sentença analisada de 1167
# 866 sentença analisada de 1167
# 867 sentença analisada de 1167
# 868 sentença analisada de 1167
# 869 sentença analisada de 1167
# 870 sentença analisada de 1167
# 871 sentença analisada de 1167
# 872 sentença analisada de 1167
# 873 sentença analisada de 1167
# 874 sentença analisada de 1167
# 875 sentença analisada de 1167
# 876 sentença analisada de 1167
# 877 sentença analisada de 1167
# 878 sentença analisada de 1167
# 879 sentença analisada de 1167
# 880 sentença analisada de 1167
# 881 sentença analisada de 1167
# 882 sentença analisada de 1167
# 883 sentença analisada de 1167
# 884 sentença analisada de 1167
# 885 sentença analisada de 1167
# 886 sentença analisada de 1167
# 887 sentença analisada de 1167
# 888 sentença analisada de 1167
# 889 sentença analisada de 1167
# 890 sentença analisada de 1167
# 891 sentença analisada de 1167
# 892 sentença analisada de 1167
# 893 sentença analisada de 1167
# 894 sentença analisada de 1167
# 895 sentença analisada de 1167
# 896 sentença analisada de 1167
# 897 sentença analisada de 1167
# 898 sentença analisada de 1167
# 899 sentença analisada de 1167
# 900 sentença analisada de 1167
# 901 sentença analisada de 1167
# 902 sentença analisada de 1167
# 903 sentença analisada de 1167
# 904 sentença analisada de 1167
# 905 sentença analisada de 1167
# 906 sentença analisada de 1167
# 907 sentença analisada de 1167
# 908 sentença analisada de 1167
# 909 sentença analisada de 1167
# 910 sentença analisada de 1167
# 911 sentença analisada de 1167
# 912 sentença analisada de 1167
# 913 sentença analisada de 1167
# 914 sentença analisada de 1167
# 915 sentença analisada de 1167
# 916 sentença analisada de 1167
# 917 sentença analisada de 1167
# 918 sentença analisada de 1167
# 919 sentença analisada de 1167
# 920 sentença analisada de 1167
# 921 sentença analisada de 1167
# 922 sentença analisada de 1167
# 923 sentença analisada de 1167
# 924 sentença analisada de 1167
# 925 sentença analisada de 1167
# 926 sentença analisada de 1167
# 927 sentença analisada de 1167
# 928 sentença analisada de 1167
# 929 sentença analisada de 1167
# 930 sentença analisada de 1167
# 931 sentença analisada de 1167
# 932 sentença analisada de 1167
# 933 sentença analisada de 1167
# 934 sentença analisada de 1167
# 935 sentença analisada de 1167
# 936 sentença analisada de 1167
# 937 sentença analisada de 1167
# 938 sentença analisada de 1167
# 939 sentença analisada de 1167
# 940 sentença analisada de 1167
# 941 sentença analisada de 1167
# 942 sentença analisada de 1167
# 943 sentença analisada de 1167
# 944 sentença analisada de 1167
# 945 sentença analisada de 1167
# 946 sentença analisada de 1167
# 947 sentença analisada de 1167
# 948 sentença analisada de 1167
# 949 sentença analisada de 1167
# 950 sentença analisada de 1167
# 951 sentença analisada de 1167
# 952 sentença analisada de 1167
# 953 sentença analisada de 1167
# 954 sentença analisada de 1167
# 955 sentença analisada de 1167
# 956 sentença analisada de 1167
# 957 sentença analisada de 1167
# 958 sentença analisada de 1167
# 959 sentença analisada de 1167
# 960 sentença analisada de 1167
# 961 sentença analisada de 1167
# 962 sentença analisada de 1167
# 963 sentença analisada de 1167
# 964 sentença analisada de 1167
# 965 sentença analisada de 1167
# 966 sentença analisada de 1167
# 967 sentença analisada de 1167
# 968 sentença analisada de 1167
# 969 sentença analisada de 1167
# 970 sentença analisada de 1167
# 971 sentença analisada de 1167
# 972 sentença analisada de 1167
# 973 sentença analisada de 1167
# 974 sentença analisada de 1167
# 975 sentença analisada de 1167
# 976 sentença analisada de 1167
# 977 sentença analisada de 1167
# 978 sentença analisada de 1167
# 979 sentença analisada de 1167
# 980 sentença analisada de 1167
# 981 sentença analisada de 1167
# 982 sentença analisada de 1167
# 983 sentença analisada de 1167
# 984 sentença analisada de 1167
# 985 sentença analisada de 1167
# 986 sentença analisada de 1167
# 987 sentença analisada de 1167
# 988 sentença analisada de 1167
# 989 sentença analisada de 1167
# 990 sentença analisada de 1167
# 991 sentença analisada de 1167
# 992 sentença analisada de 1167
# 993 sentença analisada de 1167
# 994 sentença analisada de 1167
# 995 sentença analisada de 1167
# 996 sentença analisada de 1167
# 997 sentença analisada de 1167
# 998 sentença analisada de 1167
# 999 sentença analisada de 1167
# 1000 sentença analisada de 1167
# 1001 sentença analisada de 1167
# 1002 sentença analisada de 1167
# 1003 sentença analisada de 1167
# 1004 sentença analisada de 1167
# 1005 sentença analisada de 1167
# 1006 sentença analisada de 1167
# 1007 sentença analisada de 1167
# 1008 sentença analisada de 1167
# 1009 sentença analisada de 1167
# 1010 sentença analisada de 1167
# 1011 sentença analisada de 1167
# 1012 sentença analisada de 1167
# 1013 sentença analisada de 1167
# 1014 sentença analisada de 1167
# 1015 sentença analisada de 1167
# 1016 sentença analisada de 1167
# 1017 sentença analisada de 1167
# 1018 sentença analisada de 1167
# 1019 sentença analisada de 1167
# 1020 sentença analisada de 1167
# 1021 sentença analisada de 1167
# 1022 sentença analisada de 1167
# 1023 sentença analisada de 1167
# 1024 sentença analisada de 1167
# 1025 sentença analisada de 1167
# 1026 sentença analisada de 1167
# 1027 sentença analisada de 1167
# 1028 sentença analisada de 1167
# 1029 sentença analisada de 1167
# 1030 sentença analisada de 1167
# 1031 sentença analisada de 1167
# 1032 sentença analisada de 1167
# 1033 sentença analisada de 1167
# 1034 sentença analisada de 1167
# 1035 sentença analisada de 1167
# 1036 sentença analisada de 1167
# 1037 sentença analisada de 1167
# 1038 sentença analisada de 1167
# 1039 sentença analisada de 1167
# 1040 sentença analisada de 1167
# 1041 sentença analisada de 1167
# 1042 sentença analisada de 1167
# 1043 sentença analisada de 1167
# 1044 sentença analisada de 1167
# 1045 sentença analisada de 1167
# 1046 sentença analisada de 1167
# 1047 sentença analisada de 1167
# 1048 sentença analisada de 1167
# 1049 sentença analisada de 1167
# 1050 sentença analisada de 1167
# 1051 sentença analisada de 1167
# 1052 sentença analisada de 1167
# 1053 sentença analisada de 1167
# 1054 sentença analisada de 1167
# 1055 sentença analisada de 1167
# 1056 sentença analisada de 1167
# 1057 sentença analisada de 1167
# 1058 sentença analisada de 1167
# 1059 sentença analisada de 1167
# 1060 sentença analisada de 1167
# 1061 sentença analisada de 1167
# 1062 sentença analisada de 1167
# 1063 sentença analisada de 1167
# 1064 sentença analisada de 1167
# 1065 sentença analisada de 1167
# 1066 sentença analisada de 1167
# 1067 sentença analisada de 1167
# 1068 sentença analisada de 1167
# 1069 sentença analisada de 1167
# 1070 sentença analisada de 1167
# 1071 sentença analisada de 1167
# 1072 sentença analisada de 1167
# 1073 sentença analisada de 1167
# 1074 sentença analisada de 1167
# 1075 sentença analisada de 1167
# 1076 sentença analisada de 1167
# 1077 sentença analisada de 1167
# 1078 sentença analisada de 1167
# 1079 sentença analisada de 1167
# 1080 sentença analisada de 1167
# 1081 sentença analisada de 1167
# 1082 sentença analisada de 1167
# 1083 sentença analisada de 1167
# 1084 sentença analisada de 1167
# 1085 sentença analisada de 1167
# 1086 sentença analisada de 1167
# 1087 sentença analisada de 1167
# 1088 sentença analisada de 1167
# 1089 sentença analisada de 1167
# 1090 sentença analisada de 1167
# 1091 sentença analisada de 1167
# 1092 sentença analisada de 1167
# 1093 sentença analisada de 1167
# 1094 sentença analisada de 1167
# 1095 sentença analisada de 1167
# 1096 sentença analisada de 1167
# 1097 sentença analisada de 1167
# 1098 sentença analisada de 1167
# 1099 sentença analisada de 1167
# 1100 sentença analisada de 1167
# 1101 sentença analisada de 1167
# 1102 sentença analisada de 1167
# 1103 sentença analisada de 1167
# 1104 sentença analisada de 1167
# 1105 sentença analisada de 1167
# 1106 sentença analisada de 1167
# 1107 sentença analisada de 1167
# 1108 sentença analisada de 1167
# 1109 sentença analisada de 1167
# 1110 sentença analisada de 1167
# 1111 sentença analisada de 1167
# 1112 sentença analisada de 1167
# 1113 sentença analisada de 1167
# 1114 sentença analisada de 1167
# 1115 sentença analisada de 1167
# 1116 sentença analisada de 1167
# 1117 sentença analisada de 1167
# 1118 sentença analisada de 1167
# 1119 sentença analisada de 1167
# 1120 sentença analisada de 1167
# 1121 sentença analisada de 1167
# 1122 sentença analisada de 1167
# 1123 sentença analisada de 1167
# 1124 sentença analisada de 1167
# 1125 sentença analisada de 1167
# 1126 sentença analisada de 1167
# 1127 sentença analisada de 1167
# 1128 sentença analisada de 1167
# 1129 sentença analisada de 1167
# 1130 sentença analisada de 1167
# 1131 sentença analisada de 1167
# 1132 sentença analisada de 1167
# 1133 sentença analisada de 1167
# 1134 sentença analisada de 1167
# 1135 sentença analisada de 1167
# 1136 sentença analisada de 1167
# 1137 sentença analisada de 1167
# 1138 sentença analisada de 1167
# 1139 sentença analisada de 1167
# 1140 sentença analisada de 1167
# 1141 sentença analisada de 1167
# 1142 sentença analisada de 1167
# 1143 sentença analisada de 1167
# 1144 sentença analisada de 1167
# 1145 sentença analisada de 1167
# 1146 sentença analisada de 1167
# 1147 sentença analisada de 1167
# 1148 sentença analisada de 1167
# 1149 sentença analisada de 1167
# 1150 sentença analisada de 1167
# 1151 sentença analisada de 1167
# 1152 sentença analisada de 1167
# 1153 sentença analisada de 1167
# 1154 sentença analisada de 1167
# 1155 sentença analisada de 1167
# 1156 sentença analisada de 1167
# 1157 sentença analisada de 1167
# 1158 sentença analisada de 1167
# 1159 sentença analisada de 1167
# 1160 sentença analisada de 1167
# 1161 sentença analisada de 1167
# 1162 sentença analisada de 1167
# 1163 sentença analisada de 1167
# 1164 sentença analisada de 1167
# 1165 sentença analisada de 1167
# 1166 sentença analisada de 1167
# 1167 sentença analisada de 1167

# %%
def accuracy_lemma(predicted,gold):
   acertos = len([predicted[i][j][1] for i in range(len(gold)) for j in range(len(gold[i])) if predicted[i][j][1]==gold[i][j][1]])
   totais = sum([len(sent) for sent in gold])
   return acertos/totais

def accuracy_pos(predicted,gold):
   acertos = len([predicted[i][j][2] for i in range(len(gold)) for j in range(len(gold[i])) if predicted[i][j][2]==gold[i][j][2]])
   totais = sum([len(sent) for sent in gold])
   return acertos/totais

def accuracy_feats(predicted,gold):
   acertos = len([predicted[i][j][3] for i in range(len(gold)) for j in range(len(gold[i])) if predicted[i][j][3]==gold[i][j][3]])
   totais = sum([len(sent) for sent in gold])
   return acertos/totais

print(accuracy_lemma(predicted,gold))
print(accuracy_pos(predicted,gold))
print(accuracy_feats(predicted,gold))
# Out:
# 0.7961527314881901
# 0.8219823214026952
# 0.805499203014056
